# %%
import pandas as pd 
movies = pd.read_csv('/home/lucky/KPP/bollywood.csv')
# Out:
# /home/lucky/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/lucky/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
subs = pd.read_csv('/home/lucky/KPP/subs.csv')

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='movie,lead'>

# %%
movies.value_counts().tail(20).plot(kind='pie')
# Out:
# <Axes: >

# %%
student_data = [
    [100,80,10],
    [90,70,8],
    [120,50,25],
    [80,100,8]
]

student_data = pd.DataFrame(student_data, columns=['iq','marks','package'])
student_data
# type(student_data)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        8
# 2  120     50       25
# 3   80    100        8

# %%
samidha_tutors = {
    "mentors":['Gaurav','Shivam','Ankit','Urvashi'],
    'branch':['Mechanical','Mech. and Automation','Comp. Sci','Comp. Sci.'],
    "knowledge":['Genius','Expert','Mathematician','Excellent']
}

samidha_tutors=pd.DataFrame(samidha_tutors)

type(samidha_tutors)
# Out:
# pandas.DataFrame

# %%
#we also create dataframe using CSV files, but we don't need to manually convert it into Dataframe. Because Python by default reads a csv as Dataframe.

# %%
movies.shape
# Out:
# (1500, 2)

# %%
subs.dtypes
movies.dtypes
# Out:
# movie    str
# lead     str
# dtype: object

# %%
movies.dtypes
# Out:
# movie    str
# lead     str
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
movies.columns
# Out:
# Index(['movie', 'lead'], dtype='str')

# %%
subs.columns
# Out:
# Index(['Subscribers gained'], dtype='str')

# %%
subs.values
# Out:
# array([[ 48],
#        [ 57],
#        [ 40],
#        [ 43],
#        [ 44],
#        [ 46],
#        [ 33],
#        [ 40],
#        [ 44],
#        [ 74],
#        [ 49],
#        [ 56],
#        [ 49],
#        [ 42],
#        [ 39],
#        [ 44],
#        [ 54],
#        [ 51],
#        [ 40],
#        [ 37],
#        [ 40],
#        [ 45],
#        [ 50],
#        [ 56],
#        [ 35],
#        [ 49],
#        [ 46],
#        [ 88],
#        [ 61],
#        [ 42],
#        [ 56],
#        [ 50],
#        [ 50],
#        [ 49],
#        [ 76],
#        [123],
#        [108],
#        [110],
#        [ 56],
#        [ 62],
#        [ 65],
#        [ 66],
#        [ 33],
#        [ 66],
#        [ 82],
#        [126],
#        [109],
#        [ 88],
#        [ 83],
#        [108],
#        [101],
#        [128],
#        [111],
#        [ 96],
#        [101],
#        [ 99],
#        [105],
#        [ 72],
#        [ 93],
#        [ 76],
#        [104],
#        [ 70],
# ...

# %%
student_data.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   8],
#        [120,  50,  25],
#        [ 80, 100,   8]])

# %%
subs.tail(100)
# Out:
#      Subscribers gained
# 265                 132
# 266                 119
# 267                 153
# 268                 185
# 269                 138
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [100 rows x 1 columns]

# %%
movies.head(10)
# Out:
#                                   movie                  lead
# 0              Uri: The Surgical Strike         Vicky Kaushal
# 1                         Battalion 609           Vicky Ahuja
# 2  The Accidental Prime Minister (film)           Anupam Kher
# 3                       Why Cheat India         Emraan Hashmi
# 4                       Evening Shadows      Mona Ambegaonkar
# 5                           Soni (film)  Geetika Vidya Ohlyan
# 6                         Fraud Saiyaan          Arshad Warsi
# 7                            Bombairiya          Radhika Apte
# 8      Manikarnika: The Queen of Jhansi        Kangana Ranaut
# 9                      Thackeray (film)   Nawazuddin Siddiqui

# %%
movies.sample(10)
# Out:
#                       movie               lead
# 875       Lafangey Parindey  Neil Nitin Mukesh
# 638          Baat Bann Gayi         Anisa Butt
# 1196             Prateeksha          Jeetendra
# 328          Days of Tafree          Yash Soni
# 1166  Don (2006 Hindi film)     Shah Rukh Khan
# 79               Good Newwz       Akshay Kumar
# 1259                  Insan       Akshay Kumar
# 893         Allah Ke Banday      Varun Bhagwat
# 828          Jo Hum Chahein         Sunny Gill
# 1068                Dhamaal        Sanjay Dutt

# %%
movies.describe()
# Out:
#                           movie          lead
# count                      1500          1500
# unique                     1497           566
# top     Tanu Weds Manu: Returns  Akshay Kumar
# freq                          2            48

# %%
movies.isnull().sum()
# Out:
# movie    0
# lead     0
# dtype: int64

# %%
subs.isnull().sum()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# 3

# %%
movies.sum()
# Out:
# movie    Uri: The Surgical StrikeBattalion 609The Accid...
# lead     Vicky KaushalVicky AhujaAnupam KherEmraan Hash...
# dtype: str

# %%
student_data.sum()
# Out:
# iq         390
# marks      300
# package     51
# dtype: int64

# %%
type(movies)
# Out:
# pandas.DataFrame

# %%
students = [
    [10,100,20],
    [20,120,50],
    [50,67,10]
]

students = pd.DataFrame(students, columns=['marks','iq','package'])

students.sum()
type(students)
# Out:
# pandas.DataFrame

# %%
students
# Out:
#    marks   iq  package
# 0     10  100       20
# 1     20  120       50
# 2     50   67       10

# %%
students.sum()
# Out:
# marks       80
# iq         287
# package     80
# dtype: int64

# %%
students.sum(axis=1)
# Out:
# 0    130
# 1    190
# 2    127
# dtype: int64

# %%
students.min()
# Out:
# marks      10
# iq         67
# package    10
# dtype: int64

# %%
students.mean()
# Out:
# marks      26.666667
# iq         95.666667
# package    26.666667
# dtype: float64

# %%
students.median()
# Out:
# marks       20.0
# iq         100.0
# package     20.0
# dtype: float64

# %%
students.std()
# Out:
# marks      20.816660
# iq         26.764404
# package    20.816660
# dtype: float64

# %%
students.var()
# Out:
# marks      433.333333
# iq         716.333333
# package    433.333333
# dtype: float64

# %%
type(students['marks'])
# Out:
# pandas.Series

# %%
type(students[['iq','package']])
# Out:
# pandas.DataFrame

# %%
samidha_tutors.set_index('mentors',inplace=True)
# samidha_tutors

# %%
samidha_tutors
# Out:
#                        branch      knowledge
# mentors
# Gaurav             Mechanical         Genius
# Shivam   Mech. and Automation         Expert
# Ankit               Comp. Sci  Mathematician
# Urvashi            Comp. Sci.      Excellent

# %%
movies.iloc[5]
# Out:
# movie             Soni (film)
# lead     Geetika Vidya Ohlyan
# Name: 5, dtype: str

# %%
movies.shape
# Out:
# (1500, 2)

# %%
movies.iloc[5:10]
# Out:
#                               movie                  lead
# 5                       Soni (film)  Geetika Vidya Ohlyan
# 6                     Fraud Saiyaan          Arshad Warsi
# 7                        Bombairiya          Radhika Apte
# 8  Manikarnika: The Queen of Jhansi        Kangana Ranaut
# 9                  Thackeray (film)   Nawazuddin Siddiqui

# %%
student_data
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        8
# 2  120     50       25
# 3   80    100        8

# %%
students.loc[0]
# Out:
# marks       10
# iq         100
# package     20
# Name: 0, dtype: int64

# %%
students
# Out:
#    marks   iq  package
# 0     10  100       20
# 1     20  120       50
# 2     50   67       10

# %%
samidha_tutors.loc['Gaurav':'Shivam']
# Out:
#                        branch knowledge
# mentors
# Gaurav             Mechanical    Genius
# Shivam   Mech. and Automation    Expert

# %%
ipl = pd.read_csv('/home/lucky/KPP/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[ipl['SuperOver'] == 'Y'].shape
# Out:
# (14, 20)

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
second_new_df = ipl[ipl['City'] == 'Kolkata']
second_new_df
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
second_new_df[second_new_df['WinningTeam'] == 'Chennai Super Kings'].shape[0]
# Out:
# 5

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...
